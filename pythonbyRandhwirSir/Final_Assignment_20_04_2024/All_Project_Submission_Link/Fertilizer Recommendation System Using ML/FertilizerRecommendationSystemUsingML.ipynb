# %%
import pandas as pd # pip install pandas

# %%
df = pd.read_csv('Fertilizer Recommendation.csv')
df.head()
# Out:
#    Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           26         52        38     Sandy      Maize        37          0
# 1           29         52        45     Loamy  Sugarcane        12          0
# 2           34         65        62     Black     Cotton         7          9
# 3           32         62        34       Red    Tobacco        22          0
# 4           28         54        46    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
st = df["Soil Type"].unique() # converting text values into integers for the ml algorithm
                              # soil type is unique values unique function
                              # unique function gives the unique values

print(f"Soil Type {st}")

ct = df['Crop Type'].unique()
print(f"Crop Type {ct}")

fn = df['Fertilizer Name'].unique()
print(f"Fertilizer names {fn}")
# Out:
# Soil Type ['Sandy' 'Loamy' 'Black' 'Red' 'Clayey']
# Crop Type ['Maize' 'Sugarcane' 'Cotton' 'Tobacco' 'Paddy' 'Barley' 'Wheat' 'Millets'
#  'Oil seeds' 'Pulses' 'Ground Nuts']
# Fertilizer names ['Urea' 'DAP' '14-35-14' '28-28' '17-17-17' '20-20' '10-26-26']

# %% [markdown]
# Changing the string to numeric
# the values are assigned alphabetically with first character
# for that we used label encoder
# categorical data is assigned numeric values
# if we have too many values ,just drop the coloumn based on our requirement

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Soil Type'] = le.fit_transform(df['Soil Type'])
df['Crop type'] = le.fit_transform(df['Crop Type'])
df['Fertilizer Name'] = le.fit_transform(df['Fertilizer Name'])

# %%
st = df["soil Type"].unique() # soil type values unique function
print(f"Soil Type {st}")

ct = df['Crop Type'].unique()
print(f"Crop type {ct}")

fn = df['Fertilizer Name'].unique()
print(f"Fertilizer names {fn}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'soil Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ...

# %%
df.isnull().sum()
# Out:
# Temparature        0
# Humidity           0
# Moisture           0
# Soil Type          0
# Crop Type          0
# Nitrogen           0
# Potassium          0
# Phosphorous        0
# Fertilizer Name    0
# Crop type          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Temparature  Humidity    Moisture  Soil Type   Nitrogen  Potassium  \
# count    99.000000  99.000000  99.000000  99.000000  99.000000  99.000000
# mean     30.282828  59.151515  43.181818   2.010101  18.909091   3.383838
# std       3.502304   5.840331  11.271568   1.410565  11.599693   5.814667
# min      25.000000  50.000000  25.000000   0.000000   4.000000   0.000000
# 25%      28.000000  54.000000  34.000000   1.000000  10.000000   0.000000
# 50%      30.000000  60.000000  41.000000   2.000000  13.000000   0.000000
# 75%      33.000000  64.000000  50.500000   3.000000  24.000000   7.500000
# max      38.000000  72.000000  65.000000   4.000000  42.000000  19.000000
#
#        Phosphorous  Fertilizer Name  Crop type
# count    99.000000        99.000000  99.000000
# mean     18.606061         3.636364   5.151515
# std      13.476978         1.950691   3.140790
# min       0.000000         0.000000   0.000000
# 25%       9.000000         2.000000   2.000000
# ...

# %%
x = df.drop(columns='Fertilizer Name') # prints all the columns except fn
x
# Out:
#     Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 0            26         52        38          4      Maize        37
# 1            29         52        45          2  Sugarcane        12
# 2            34         65        62          0     Cotton         7
# 3            32         62        34          3    Tobacco        22
# 4            28         54        46          1      Paddy        35
# ..          ...        ...       ...        ...        ...       ...
# 94           25         50        32          1     Pulses        24
# 95           30         60        27          3    Tobacco         4
# 96           38         72        51          2      Wheat        39
# 97           36         60        43          4    Millets        15
# 98           29         58        57          0  Sugarcane        12
#
#     Potassium  Phosphorous  Crop type
# 0           0            0          3
# 1           0           36          8
# ...

# %%
y = df['Fertilizer Name']
y
# Out:
# 0     6
# 1     5
# 2     1
# 3     4
# 4     6
#      ..
# 94    4
# 95    0
# 96    6
# 97    5
# 98    3
# Name: Fertilizer Name, Length: 99, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_test.head())
print(y_test.head())
# Out:
#     Temparature  Humidity   Moisture  Soil Type Crop Type  Nitrogen  \
# 26           30         60        63          3    Cotton         9
# 86           29         58        30          3   Tobacco        13
# 2            34         65        62          0    Cotton         7
# 55           27         53        43          0   Millets        23
# 75           29         58        42          1     Paddy         9
#
#     Potassium  Phosphorous  Crop type
# 26          9           29          1
# 86         17           16          9
# 2           9           30          1
# 55          0           24          4
# 75         10           22          6
# 26    1
# 86    0
# 2     1
# 55    4
# 75    1
# Name: Fertilizer Name, dtype: int32

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error

# %%
kn = KNeighborsClassifier(n_neighbors=5)
s = SVC()
rf = RandomForestClassifier()
dt = DecisionTreeClassifier()

rf.fit(x_train,y_train)
dt.fit(x_train, y_train)
s.fit(x_train,y_train)
kn.fit(x_train, y_train)

y_pred2 = rf.predict(x_test)
y_pred1 = dt.predict(x_test) # for the user input
# it prints the output

y_pred3 = s.predict(x_test)
y_pred4 = kn.predict(x_test) # for the user input
# for trainning data set ,it gives a lot output bcoz trainning data is large


print(f"Decision tree {y_pred1} accuracy is {mean_absolute_error(y_test,y_pred1)}")
print(f"Random Forset {y_pred2} accuracy is {mean_absolute_error(y_test,y_pred2)}")
print(f"Support Vector classifier {y_pred3} accuracy is {mean_absolute_error(y_test,y_pred3)}")
print(f"Kneighbour classifier {y_pred4} accuracy is {mean_absolute_error(y_test,y_pred4)}")
